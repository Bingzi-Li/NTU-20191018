# %% [markdown]
# # Data Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import json

sns.set(style='whitegrid')

# %% [markdown]
# ## 1 Data Integration

# %% [markdown]
# ### 1.1 Read tmdb_5000_movies.csv

# %%
movies_df = pd.read_csv('data/tmdb_5000_movies.csv')
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
movies_df.shape
# Out:
# (4803, 20)

# %% [markdown]
# Look into the first data input for more details of the features

# %%
movies_df.loc[0, 'overview']
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
avatar_genres = pd.DataFrame(json.loads(movies_df.loc[0, 'genres']))
avatar_genres
# Out:
#     id             name
# 0   28           Action
# 1   12        Adventure
# 2   14          Fantasy
# 3  878  Science Fiction

# %%
avatar_keywords =  pd.DataFrame(json.loads(movies_df.loc[0, 'keywords']))
avatar_keywords
# Out:
#         id             name
# 0     1463    culture clash
# 1     2964           future
# 2     3386        space war
# 3     3388     space colony
# 4     3679          society
# 5     3801     space travel
# 6     9685       futuristic
# 7     9840          romance
# 8     9882            space
# 9     9951            alien
# 10   10148            tribe
# 11   10158     alien planet
# 12   10987              cgi
# 13   11399           marine
# 14   13065          soldier
# 15   14643           battle
# 16   14720      love affair
# 17  165431         anti war
# 18  193554  power relations
# 19  206690    mind and soul
# 20  209714               3d

# %%
avatar_production_companies =  pd.DataFrame(json.loads(movies_df.loc[0, 'production_companies']))
avatar_production_companies
# Out:
#                                      name   id
# 0                 Ingenious Film Partners  289
# 1  Twentieth Century Fox Film Corporation  306
# 2                      Dune Entertainment  444
# 3                Lightstorm Entertainment  574

# %%
avatar_production_countries =  pd.DataFrame(json.loads(movies_df.loc[0, 'production_countries']))
avatar_production_countries
# Out:
#   iso_3166_1                      name
# 0         US  United States of America
# 1         GB            United Kingdom

# %%
avatar_spoken_languages =  pd.DataFrame(json.loads(movies_df.loc[0, 'spoken_languages']))
avatar_spoken_languages
# Out:
#   iso_639_1     name
# 0        en  English
# 1        es  Español

# %% [markdown]
# ### 1.2 Read tmdb_5000_credits.csv

# %%
credits_df = pd.read_csv('data/tmdb_5000_credits.csv')
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
credits_df.shape
# Out:
# (4803, 4)

# %% [markdown]
# Look into the first data input for more details of the features

# %%
credits_df.iloc[0]
# Out:
# movie_id                                                19995
# title                                                  Avatar
# cast        [{"cast_id": 242, "character": "Jake Sully", "...
# crew        [{"credit_id": "52fe48009251416c750aca23", "de...
# Name: 0, dtype: object

# %%
avatar_cast = pd.DataFrame(json.loads(credits_df.loc[0, 'cast']))
avatar_cast.head(20)
# Out:
#     cast_id                  character                 credit_id  gender  \
# 0       242                 Jake Sully  5602a8a7c3a3685532001c9a       2
# 1         3                    Neytiri  52fe48009251416c750ac9cb       1
# 2        25        Dr. Grace Augustine  52fe48009251416c750aca39       1
# 3         4              Col. Quaritch  52fe48009251416c750ac9cf       2
# 4         5               Trudy Chacon  52fe48009251416c750ac9d3       1
# 5         8                  Selfridge  52fe48009251416c750ac9e1       2
# 6         7              Norm Spellman  52fe48009251416c750ac9dd       2
# 7         9                       Moat  52fe48009251416c750ac9e5       1
# 8        11                    Eytukan  52fe48009251416c750ac9ed       2
# 9        10                    Tsu'Tey  52fe48009251416c750ac9e9       2
# 10       12              Dr. Max Patel  52fe48009251416c750ac9f1       2
# 11       13             Lyle Wainfleet  52fe48009251416c750ac9f5       2
# 12       32               Private Fike  52fe48009251416c750aca5b       2
# 13       33        Cryo Vault Med Tech  52fe48009251416c750aca5f       2
# 14       34    Venture Star Crew Chief  52fe48009251416c750aca63       2
# 15       35            Lock Up Trooper  52fe48009251416c750aca67       2
# 16       36              Shuttle Pilot  52fe48009251416c750aca6b       0
# 17       37           Shuttle Co-Pilot  52fe48009251416c750aca6f       0
# 18       38         Shuttle Crew Chief  52fe48009251416c750aca73       2
# 19       39  Tractor Operator / Troupe  52fe48009251416c750aca77       0
#
#          id                 name  order
# 0     65731      Sam Worthington      0
# 1      8691          Zoe Saldana      1
# 2     10205     Sigourney Weaver      2
# 3     32747         Stephen Lang      3
# 4     17647   Michelle Rodriguez      4
# 5      1771      Giovanni Ribisi      5
# 6     59231     Joel David Moore      6
# 7     30485          CCH Pounder      7
# 8     15853            Wes Studi      8
# 9     10964           Laz Alonso      9
# 10    95697           Dileep Rao     10
# 11    98215          Matt Gerald     11
# 12   154153   Sean Anthony Moran     12
# 13   397312          Jason Whyte     13
# 14    42317       Scott Lawrence     14
# 15   986734        Kelly Kilgour     15
# 16  1207227   James Patrick Pitt     16
# 17  1180936  Sean Patrick Murphy     17
# 18  1019578         Peter Dillon     18
# 19    91443         Kevin Dorman     19

# %%
avatar_crew = pd.DataFrame(json.loads(credits_df.loc[0, 'crew']))
avatar_crew.head(20)
# Out:
#                    credit_id         department  gender    id  \
# 0   52fe48009251416c750aca23            Editing       0  1721
# 1   539c47ecc3a36810e3001f87                Art       2   496
# 2   54491c89c3a3680fb4001cf7              Sound       0   900
# 3   54491cb70e0a267480001bd0              Sound       0   900
# 4   539c4a4cc3a36810c9002101         Production       1  1262
# 5   5544ee3b925141499f0008fc              Sound       2  1729
# 6   52fe48009251416c750ac9c3          Directing       2  2710
# 7   52fe48009251416c750ac9d9            Writing       2  2710
# 8   52fe48009251416c750aca17            Editing       2  2710
# 9   52fe48009251416c750aca29         Production       2  2710
# 10  52fe48009251416c750aca3f            Writing       2  2710
# 11  539c4987c3a36810ba0021a4                Art       2  7236
# 12  549598c3c3a3686ae9004383     Visual Effects       0  6690
# 13  52fe48009251416c750aca4b         Production       1  6347
# 14  570b6f419251417da70032fe                Art       2  6878
# 15  5495a0fac3a3686ae9004468              Sound       0  6883
# 16  54959706c3a3686af3003e81              Sound       0  8159
# 17  54491d58c3a3680fb1001ccb              Sound       0  8160
# 18  54491d6cc3a3680fa5001b2c              Sound       0  8163
# 19  52fe48009251416c750aca57  Costume & Make-Up       1  8527
#
#                          job                name
# 0                     Editor   Stephen E. Rivkin
# 1          Production Design         Rick Carter
# 2             Sound Designer   Christopher Boyes
# 3   Supervising Sound Editor   Christopher Boyes
# 4                    Casting           Mali Finn
# 5    Original Music Composer        James Horner
# 6                   Director       James Cameron
# 7                     Writer       James Cameron
# 8                     Editor       James Cameron
# 9                   Producer       James Cameron
# 10                Screenplay       James Cameron
# 11             Art Direction      Andrew Menzies
# 12   Visual Effects Producer         Jill Brooks
# 13                   Casting      Margery Simkin
# 14  Supervising Art Director       Kevin Ishioka
# 15              Music Editor      Dick Bernstein
# 16      Sound Effects Editor       Shannon Mills
# 17                     Foley       Dennie Thorpe
# 18                     Foley          Jana Vance
# 19            Costume Design  Deborah Lynn Scott

# %% [markdown]
# ### 1.3 Merge of two data frame

# %%
movies_df['id'].nunique()
# Out:
# 4803

# %% [markdown]
# ID is unique for each row in the data frame

# %%
movies_df['title'].nunique()
# Out:
# 4800

# %% [markdown]
# Duplicated titles are found in the data frame

# %%
movies_df[movies_df['title'].duplicated()]['title']
# Out:
# 2877           The Host
# 3693    Out of the Blue
# 4267             Batman
# Name: title, dtype: object

# %%
movies_df[movies_df['title']=='The Host']
# Out:
#         budget                                             genres  \
# 972   44000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 2877  11000000  [{"id": 27, "name": "Horror"}, {"id": 18, "nam...
#
#                        homepage     id  \
# 972                         NaN  72710
# 2877  http://www.hostmovie.com/   1255
#
#                                                keywords original_language  \
# 972   [{"id": 818, "name": "based on novel"}, {"id":...                en
# 2877  [{"id": 1261, "name": "river"}, {"id": 1880, "...                ko
#
#      original_title                                           overview  \
# 972        The Host  A parasitic alien soul is injected into the bo...
# 2877             괴물  Gang-du is a dim-witted man working at his fat...
#
#       popularity                               production_companies  \
# 972    42.933027  [{"name": "Nick Wechsler Productions", "id": 8...
# 2877   27.655270  [{"name": "Cineclick Asia", "id": 685}, {"name...
#
#                                    production_countries release_date  \
# 972   [{"iso_3166_1": "US", "name": "United States o...   2013-03-22
# 2877      [{"iso_3166_1": "KR", "name": "South Korea"}]   2006-07-27
#
#        revenue  runtime                                   spoken_languages  \
# 972   63327201    125.0           [{"iso_639_1": "en", "name": "English"}]
# 2877  88489643    119.0  [{"iso_639_1": "ko", "name": "\ud55c\uad6d\uc5...
#
#         status                tagline     title  vote_average  vote_count
# 972   Released  You will be one of us  The Host           6.0        1817
# 2877  Released     Monsters are real.  The Host           6.7         537

# %%
movies_df[movies_df['title']=='Out of the Blue']
# Out:
#       budget                         genres homepage     id  \
# 3647       0  [{"id": 18, "name": "Drama"}]      NaN  39269
# 3693       0  [{"id": 18, "name": "Drama"}]      NaN  10844
#
#                                                keywords original_language  \
# 3647  [{"id": 4470, "name": "punk"}, {"id": 10183, "...                en
# 3693  [{"id": 2658, "name": "new zealand"}, {"id": 3...                en
#
#        original_title                                           overview  \
# 3647  Out of the Blue  Dennis Hopper is a hard-drinking truck driver ...
# 3693  Out of the Blue  Ordinary people find extraordinary courage in ...
#
#       popularity                      production_companies  \
# 3647    0.679351  [{"name": "Robson Street", "id": 71953}]
# 3693    0.706355                                        []
#
#                                production_countries release_date  revenue  \
# 3647       [{"iso_3166_1": "CA", "name": "Canada"}]   1980-05-01        0
# 3693  [{"iso_3166_1": "NZ", "name": "New Zealand"}]   2006-10-12        0
#
#       runtime                          spoken_languages    status  \
# 3647     94.0  [{"iso_639_1": "en", "name": "English"}]  Released
# 3693    103.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline            title  \
# 3647  A harrowing drama from the director of Easy Rider  Out of the Blue
# 3693            The true story of a small town massacre  Out of the Blue
#
#       vote_average  vote_count
# 3647           6.5          17
# 3693           5.9          18

# %%
movies_df[movies_df['title']=='Batman']
# Out:
#         budget                                             genres homepage  \
# 1359  35000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...      NaN
# 4267   1377800  [{"id": 10751, "name": "Family"}, {"id": 12, "...      NaN
#
#         id                                           keywords  \
# 1359   268  [{"id": 848, "name": "double life"}, {"id": 84...
# 4267  2661  [{"id": 339, "name": "submarine"}, {"id": 849,...
#
#      original_language original_title  \
# 1359                en         Batman
# 4267                en         Batman
#
#                                                overview  popularity  \
# 1359  The Dark Knight of Gotham City begins his war ...   44.104469
# 4267  The Dynamic Duo faces four super-villains who ...    9.815394
#
#                                    production_companies  \
# 1359  [{"name": "PolyGram Filmed Entertainment", "id...
# 4267  [{"name": "Twentieth Century Fox Film Corporat...
#
#                                    production_countries release_date  \
# 1359  [{"iso_3166_1": "GB", "name": "United Kingdom"...   1989-06-23
# 4267  [{"iso_3166_1": "US", "name": "United States o...   1966-07-30
#
#         revenue  runtime                                   spoken_languages  \
# 1359  411348924    126.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 4267          0    105.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline   title  \
# 1359  Released  Have you ever danced with the devil in the pal...  Batman
# 4267  Released           He's Here Big As Life In A Real Bat-Epic  Batman
#
#       vote_average  vote_count
# 1359           7.0        2096
# 4267           6.1         203

# %% [markdown]
# Duplicated titles in the data frame come from different movies having the same title

# %%
np.sum(movies_df['id']==credits_df['movie_id'])
# Out:
# 4803

# %% [markdown]
# ID column and Movie ID column in two data frames are prefectly aligned

# %%
tmdb_df = movies_df.copy()
tmdb_df[['cast', 'crew']] = credits_df[['cast', 'crew']]
tmdb_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ...     revenue runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...  2787965087   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   961000000   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   880674609   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...  1084939099   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   284139100   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 22 columns]

# %%
tmdb_features = sorted(list(tmdb_df.columns.drop(['id','title'])))
tmdb_df = tmdb_df.reindex(['id','title']+tmdb_features, axis=1)
tmdb_df.head()
# Out:
#        id                                     title     budget  \
# 0   19995                                    Avatar  237000000
# 1     285  Pirates of the Caribbean: At World's End  300000000
# 2  206647                                   Spectre  245000000
# 3   49026                     The Dark Knight Rises  250000000
# 4   49529                               John Carter  260000000
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage  \
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
# 4          http://movies.disney.com/john-carter
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  ...  \
# 0                                    Avatar  ...
# 1  Pirates of the Caribbean: At World's End  ...
# 2                                   Spectre  ...
# 3                     The Dark Knight Rises  ...
# 4                               John Carter  ...
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#   runtime                                   spoken_languages    status  \
# 0   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1   169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2   148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3   165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4   132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline vote_average vote_count
# 0                     Enter the World of Pandora.          7.2      11800
# 1  At the end of the world, the adventure begins.          6.9       4500
# 2                           A Plan No One Escapes          6.3       4466
# 3                                 The Legend Ends          7.6       9106
# 4            Lost in our world, found in another.          6.1       2124
#
# [5 rows x 22 columns]

# %%
tmdb_df.to_csv('output/tmdb_5000.csv', index=False)

# %% [markdown]
# ## 2 Data Cleaning

# %%
tmdb_df = pd.read_csv('output/tmdb_5000.csv')
tmdb_df.head()
# Out:
#        id                                     title     budget  \
# 0   19995                                    Avatar  237000000
# 1     285  Pirates of the Caribbean: At World's End  300000000
# 2  206647                                   Spectre  245000000
# 3   49026                     The Dark Knight Rises  250000000
# 4   49529                               John Carter  260000000
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage  \
# 0                   http://www.avatarmovie.com/
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
# 4          http://movies.disney.com/john-carter
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  ...  \
# 0                                    Avatar  ...
# 1  Pirates of the Caribbean: At World's End  ...
# 2                                   Spectre  ...
# 3                     The Dark Knight Rises  ...
# 4                               John Carter  ...
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#   runtime                                   spoken_languages    status  \
# 0   162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1   169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2   148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3   165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4   132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline vote_average vote_count
# 0                     Enter the World of Pandora.          7.2      11800
# 1  At the end of the world, the adventure begins.          6.9       4500
# 2                           A Plan No One Escapes          6.3       4466
# 3                                 The Legend Ends          7.6       9106
# 4            Lost in our world, found in another.          6.1       2124
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 2.1 Feature "Homepage"

# %%
valid_homepage = tmdb_df['homepage'].count()
valid_homepage, valid_homepage/len(tmdb_df)
# Out:
# (1712, 0.3564438892358942)

# %%
tmdb_df.drop(['homepage'], axis=1, inplace=True)

# %% [markdown]
# Less than 40% of the movies in the table have valid homepage, inconsistent and irrelevant data

# %% [markdown]
# ### 2.2 Feature "Status"

# %%
tmdb_df['status'].value_counts()
# Out:
# Released           4795
# Rumored               5
# Post Production       3
# Name: status, dtype: int64

# %%
tmdb_df[tmdb_df['status']=='Rumored']
# Out:
#          id                     title  budget  \
# 4401  43630       The Helix... Loaded       0
# 4453  57294      Crying with Laughter       0
# 4508  70875  The Harvest (La Cosecha)   56000
# 4662  40963            Little Big Top       0
# 4754  84659             The Naked Ape       0
#
#                                                    cast  \
# 4401                                                 []
# 4453  [{"cast_id": 3, "character": "Joey Frisk", "cr...
# 4508                                                 []
# 4662  [{"cast_id": 0, "character": "Seymour", "credi...
# 4754  [{"cast_id": 1, "character": "Alex", "credit_i...
#
#                                                    crew  \
# 4401                                                 []
# 4453  [{"credit_id": "52fe492dc3a36847f818d031", "de...
# 4508  [{"credit_id": "52fe4816c3a368484e0e8bbd", "de...
# 4662                                                 []
# 4754  [{"credit_id": "52fe49049251416c910a00b3", "de...
#
#                                                  genres  \
# 4401  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 4453  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4508                [{"id": 99, "name": "Documentary"}]
# 4662                     [{"id": 35, "name": "Comedy"}]
# 4754  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
#                                                keywords original_language  \
# 4401                                                 []                en
# 4453  [{"id": 1930, "name": "kidnapping"}, {"id": 97...                en
# 4508  [{"id": 1729, "name": "migration"}, {"id": 190...                en
# 4662        [{"id": 10183, "name": "independent film"}]                en
# 4754                                                 []                en
#
#                 original_title  \
# 4401       The Helix... Loaded
# 4453      Crying with Laughter
# 4508  The Harvest (La Cosecha)
# 4662            Little Big Top
# 4754             The Naked Ape
#
#                                                overview  ...  \
# 4401                                                     ...
# 4453  Powerfully redemptive and darkly comedic reven...  ...
# 4508  The story of the children who work 12-14 hour ...  ...
# 4662  An aging out of work clown returns to his smal...  ...
# 4754  The Naked Ape is a coming-of-age film followin...  ...
#
#                                    production_companies  \
# 4401                                                 []
# 4453  [{"name": "Scottish Screen", "id": 698}, {"nam...
# 4508                                                 []
# 4662          [{"name": "Fly High Films", "id": 24248}]
# 4754                                                 []
#
#                                    production_countries release_date revenue  \
# 4401  [{"iso_3166_1": "US", "name": "United States o...   2005-01-01       0
# 4453   [{"iso_3166_1": "GB", "name": "United Kingdom"}]   2009-06-01       0
# 4508                                                 []   2011-07-29       0
# 4662  [{"iso_3166_1": "US", "name": "United States o...   2006-01-01       0
# 4754                                                 []   2006-09-16       0
#
#       runtime                          spoken_languages   status  \
# 4401     97.0  [{"iso_639_1": "en", "name": "English"}]  Rumored
# 4453     93.0  [{"iso_639_1": "en", "name": "English"}]  Rumored
# 4508     80.0                                        []  Rumored
# 4662      0.0  [{"iso_639_1": "en", "name": "English"}]  Rumored
# 4754    110.0                                        []  Rumored
#
#                           tagline vote_average  vote_count
# 4401                          NaN          4.8           2
# 4453  A Bad Trip Down Memory Lane          7.0           1
# 4508                          NaN          0.0           0
# 4662                          NaN         10.0           1
# 4754                          NaN          5.0           1
#
# [5 rows x 21 columns]

# %%
tmdb_df['status'].value_counts()[1]/len(tmdb_df)
# Out:
# 0.0010410160316468874

# %%
tmdb_df[tmdb_df['status']=='Post Production']
# Out:
#           id            title   budget  \
# 2906  357837  Dancin' It's On        0
# 4169  295886   Brotherly Love  1900000
# 4178   50875    Higher Ground  2000000
#
#                                                    cast  \
# 2906  [{"cast_id": 0, "character": "Jennifer", "cred...
# 4169  [{"cast_id": 1, "character": "Jackie Taylor", ...
# 4178  [{"cast_id": 6, "character": "Corinne Walker",...
#
#                                                    crew  \
# 2906  [{"credit_id": "55e85c30c3a3682c62002869", "de...
# 4169  [{"credit_id": "54d3585cc3a3686ab90036ff", "de...
# 4178  [{"credit_id": "52fe47dac3a36847f814bcb5", "de...
#
#                                                  genres  \
# 2906  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4169                      [{"id": 18, "name": "Drama"}]
# 4178  [{"id": 18, "name": "Drama"}, {"id": 53, "name...
#
#                                                keywords original_language  \
# 2906  [{"id": 246, "name": "dancing"}, {"id": 271, "...                cs
# 4169                                                 []                en
# 4178  [{"id": 1009, "name": "baby"}, {"id": 1157, "n...                en
#
#        original_title                                           overview  ...  \
# 2906  Dancin' It's On  This coming of age Dance Film, in the spirit o...  ...
# 4169   Brotherly Love  West Philadelphia basketball star Sergio Taylo...  ...
# 4178    Higher Ground  A chronicle of one woman's lifelong struggle w...  ...
#
#       production_companies                               production_countries  \
# 2906                    []  [{"iso_3166_1": "US", "name": "United States o...
# 4169                    []                                                 []
# 4178                    []  [{"iso_3166_1": "US", "name": "United States o...
#
#      release_date revenue  runtime                          spoken_languages  \
# 2906   2015-10-16       0     89.0  [{"iso_639_1": "en", "name": "English"}]
# 4169   2015-04-24       0     89.0  [{"iso_639_1": "en", "name": "English"}]
# 4178   2011-08-26  841733    109.0  [{"iso_639_1": "en", "name": "English"}]
#
#                status                                tagline vote_average  \
# 2906  Post Production  Dancin' Like You've Never Seen Before          4.3
# 4169  Post Production                                    NaN          6.9
# 4178  Post Production                                    NaN          5.3
#
#       vote_count
# 2906           2
# 4169          21
# 4178          14
#
# [3 rows x 21 columns]

# %%
tmdb_df['status'].value_counts()[2]/len(tmdb_df)
# Out:
# 0.0006246096189881324

# %%
tmdb_df = tmdb_df[tmdb_df['status']=='Released']
tmdb_df.drop(['status'], axis=1, inplace=True)

# %% [markdown]
# Insignificant portion of movies, most of which are not popular, of status 'Rumored' and 'Post Production'

# %%
tmdb_df.count()==len(tmdb_df)
# Out:
# id                       True
# title                    True
# budget                   True
# cast                     True
# crew                     True
# genres                   True
# keywords                 True
# original_language        True
# original_title           True
# overview                False
# popularity               True
# production_companies     True
# production_countries     True
# release_date            False
# revenue                  True
# runtime                 False
# spoken_languages         True
# tagline                 False
# vote_average             True
# vote_count               True
# dtype: bool

# %% [markdown]
# ### 2.3 Feature "Overview"

# %%
tmdb_df['overview'].apply(type).value_counts()
# Out:
# <class 'str'>      4792
# <class 'float'>       3
# Name: overview, dtype: int64

# %%
tmdb_df[tmdb_df['overview'].apply(lambda x: type(x)!=str)]
# Out:
#           id                                       title    budget  \
# 2656  370980  Chiamatemi Francesco - Il Papa della gente  15000000
# 4140  459488                 To Be Frank, Sinatra at 100         2
# 4431  292539                                 Food Chains    913000
#
#                                                    cast  \
# 2656  [{"cast_id": 5, "character": "Jorge Mario Berg...
# 4140  [{"cast_id": 0, "character": "Narrator", "cred...
# 4431                                                 []
#
#                                                    crew  \
# 2656  [{"credit_id": "5660019ac3a36875f100252b", "de...
# 4140  [{"credit_id": "592b25e4c3a368783e065a2f", "de...
# 4431  [{"credit_id": "5470c3b1c3a368085e000abd", "de...
#
#                                    genres  \
# 2656        [{"id": 18, "name": "Drama"}]
# 4140  [{"id": 99, "name": "Documentary"}]
# 4431  [{"id": 99, "name": "Documentary"}]
#
#                                                keywords original_language  \
# 2656  [{"id": 717, "name": "pope"}, {"id": 5565, "na...                it
# 4140  [{"id": 6027, "name": "music"}, {"id": 225822,...                en
# 4431                                                 []                de
#
#                                   original_title overview  popularity  \
# 2656  Chiamatemi Francesco - Il Papa della gente      NaN    0.738646
# 4140                 To Be Frank, Sinatra at 100      NaN    0.050625
# 4431                                 Food Chains      NaN    0.795698
#
#                                   production_companies  \
# 2656            [{"name": "Taodue Film", "id": 45724}]
# 4140  [{"name": "Eyeline Entertainment", "id": 60343}]
# 4431                                                []
#
#                                   production_countries release_date  revenue  \
# 2656           [{"iso_3166_1": "IT", "name": "Italy"}]   2015-12-03        0
# 4140  [{"iso_3166_1": "GB", "name": "United Kingdom"}]   2015-12-12        0
# 4431                                                []   2014-04-26        0
#
#       runtime                               spoken_languages tagline  \
# 2656      NaN  [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]     NaN
# 4140      NaN                                             []     NaN
# 4431     83.0       [{"iso_639_1": "en", "name": "English"}]     NaN
#
#       vote_average  vote_count
# 2656           7.3          12
# 4140           0.0           0
# 4431           7.4           8

# %%
tmdb_df['overview'].str.len().describe()
# Out:
# count    4792.000000
# mean      305.595576
# std       162.663506
# min        23.000000
# 25%       178.000000
# 50%       284.000000
# 75%       392.000000
# max      1000.000000
# Name: overview, dtype: float64

# %%
tmdb_df = tmdb_df[tmdb_df['overview'].apply(lambda x: type(x)==str)]

# %% [markdown]
# Insignificant portion of movies, most of which are not popular, without a proper overview

# %%
tmdb_df.count()==len(tmdb_df)
# Out:
# id                       True
# title                    True
# budget                   True
# cast                     True
# crew                     True
# genres                   True
# keywords                 True
# original_language        True
# original_title           True
# overview                 True
# popularity               True
# production_companies     True
# production_countries     True
# release_date            False
# revenue                  True
# runtime                  True
# spoken_languages         True
# tagline                 False
# vote_average             True
# vote_count               True
# dtype: bool

# %% [markdown]
# ### 2.4 Feature "Release Date"

# %%
tmdb_df['release_date'].apply(type).value_counts()
# Out:
# <class 'str'>      4791
# <class 'float'>       1
# Name: release_date, dtype: int64

# %%
tmdb_df[tmdb_df['release_date'].apply(lambda x: type(x)!=str)]
# Out:
#           id                       title  budget cast crew genres keywords  \
# 4553  380097  America Is Still the Place       0   []   []     []       []
#
#      original_language              original_title  \
# 4553                en  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaN        0      0.0
#
#      spoken_languages tagline  vote_average  vote_count
# 4553               []     NaN           0.0           0

# %%
tmdb_df = tmdb_df[tmdb_df['release_date'].apply(lambda x: type(x)==str)]

# %% [markdown]
# Obviously invalid data

# %%
tmdb_df.count()==len(tmdb_df)
# Out:
# id                       True
# title                    True
# budget                   True
# cast                     True
# crew                     True
# genres                   True
# keywords                 True
# original_language        True
# original_title           True
# overview                 True
# popularity               True
# production_companies     True
# production_countries     True
# release_date             True
# revenue                  True
# runtime                  True
# spoken_languages         True
# tagline                 False
# vote_average             True
# vote_count               True
# dtype: bool

# %% [markdown]
# ### 2.5 Feature "Tagline"

# %%
tmdb_df['tagline'].apply(type).value_counts()
# Out:
# <class 'str'>      3957
# <class 'float'>     834
# Name: tagline, dtype: int64

# %%
tmdb_df['tagline'].apply(type).value_counts()[1]/len(tmdb_df)
# Out:
# 0.17407639323731997

# %%
tmdb_df['tagline'].str.len().describe()
# Out:
# count    3957.000000
# mean       41.993935
# std        24.268613
# min         3.000000
# 25%        26.000000
# 50%        36.000000
# 75%        52.000000
# max       252.000000
# Name: tagline, dtype: float64

# %%
tmdb_df['tagline'].head()
# Out:
# 0                       Enter the World of Pandora.
# 1    At the end of the world, the adventure begins.
# 2                             A Plan No One Escapes
# 3                                   The Legend Ends
# 4              Lost in our world, found in another.
# Name: tagline, dtype: object

# %%
tmdb_df.drop(['tagline'], axis=1, inplace=True)

# %% [markdown]
# Tagline is not important for data mining in this case as more detailed information is given by the overview

# %%
tmdb_df.count()==len(tmdb_df)
# Out:
# id                      True
# title                   True
# budget                  True
# cast                    True
# crew                    True
# genres                  True
# keywords                True
# original_language       True
# original_title          True
# overview                True
# popularity              True
# production_companies    True
# production_countries    True
# release_date            True
# revenue                 True
# runtime                 True
# spoken_languages        True
# vote_average            True
# vote_count              True
# dtype: bool

# %%
tmdb_df.to_csv('output/tmdb_5000_cleaned.csv', index=False)
